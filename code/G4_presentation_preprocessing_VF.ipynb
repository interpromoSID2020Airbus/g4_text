# %%
"""
    Created on 16 January 2020
    Group 4
    Authors : group 4
"""
# Out:
# '\n    Created on 16 January 2020\n    Group 4\n    Authors : group 4\n'

# %% [markdown]
# # Preprocessing Facet

# %%
# %run G4_facet_preprocessing_VF.ipynb #Take time because of reading a 2 Go file

# %% [markdown]
# Computes the different tf-idf matrix.

# %%
TF_IDF_apply('ALL_DATA_ANNOTATE', column = 'Sentence', extension = 'xlsx')

# %%
TF_IDF_apply('airline_qual_sentence_1000', column = 'Sentence', extension = 'csv')
# Out:
# Comment not English
# Comment not English
# Comment not English
# Comment not English
# Comment not English
# Comment not English

# %% [markdown]
# Computes the different Embedding matrix.

# %%
embedding('ALL_DATA_ANNOTATE')
# Out:
# Matrice embedding de ALL_DATA_ANNOTATE enregistrée

# %%
embedding('airline_qual_sentence_1000')
# Out:
# 540/8211
# /home/cmi-sid/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: RuntimeWarning: invalid value encountered in true_divide
# Matrice embedding de airline_qual_sentence_1000 enregistrée

# %%
weight_embedding('ALL_DATA_ANNOTATE')
# Out:
#       index         1         2         3         4         5         6  \
# 0         0  0.006510 -0.207315  0.195990  0.031964  0.042394  0.099783
# 1         1 -0.498249  0.277159 -0.247201 -0.057836  0.197238 -0.070183
# 2         2 -0.013228 -0.073346  0.142675  0.003573  0.243431  0.177318
# 3         3 -0.021551 -0.275081  0.092197 -0.031869  0.160059  0.409881
# 4         4  0.240661  0.221633  0.118041  0.425112  0.328874  0.575225
# ...     ...       ...       ...       ...       ...       ...       ...
# 5798   6034 -0.017614 -0.129301 -0.003218  0.158390  0.025522  0.388599
# 5799   6035 -0.012137  0.258999 -0.059103 -0.174376  0.114558  0.255566
# 5800   6036 -0.032608  0.393708 -0.017129 -0.062880  0.248158  0.150760
# 5801   6037  0.228580  0.039659 -0.033766  0.063943  0.084255  0.103222
# 5802   6038 -0.148434  0.345148  0.326986 -0.147639 -0.108775  0.006146
#
#              7         8         9  ...       191       192       193  \
# ...

# %%
weight_embedding('airline_qual_sentence_1000')
# Out:
#       index         1         2         3         4         5         6  \
# 0         0       NaN       NaN       NaN       NaN       NaN       NaN
# 1         1 -0.280286 -0.083267 -0.120251 -0.041395 -0.366766  0.005017
# 2         2 -0.128183  0.050360 -0.188422  0.065321 -0.109858 -0.016743
# 3         3  0.123573 -0.014192 -0.400585  0.142927  0.046349  0.478956
# 4         4  0.371636  0.156681 -0.199158  0.048880  0.188453 -0.136521
# ...     ...       ...       ...       ...       ...       ...       ...
# 8206   8270  0.009556  0.271448 -0.212181  0.017107 -0.014647  0.233159
# 8207   8271 -0.088859 -0.284242 -0.036180  0.163250  0.541925  0.025657
# 8208   8272  0.015937  0.128828 -0.145301 -0.150994 -0.172558 -0.041010
# 8209   8273 -0.046957 -0.007680  0.239098 -0.061273  0.006329 -0.084559
# 8210   8274 -0.268685  0.045377 -0.266695  0.312053 -0.074276  0.058709
#
#              7         8         9  ...       191       192       193  \
# ...

# %%
metric_purity('ALL_DATA_ANNOTATE')

# %% [markdown]
# # Preprocessing Opinion

# %%
# %run G4_opinion_preprocessing_VF.ipynb

# %% [markdown]
# Imports and cleanses the data.

# %%
data, label = main(review, label_mean(label))

# %% [markdown]
# Split the data in train and test splits.

# %%
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.30, random_state=42)

# %%
tf_idf_train = tf_idf(X_train, X_train)
tf_idf_test = tf_idf(X_train, X_test)
# Out:
# Taille de la matrice X :  (3960, 4813)
# Taille de la matrice X :  (1698, 4813)

# %% [markdown]
# Creates the labels and data sets for Deep Learning.

# %%
target = label.values + 1 
y_neural_network = to_categorical(target, num_classes=3)

# %%
X_pred = pd.read_csv("../data/airline_qual_sentence_1000.csv")

X_pred = X_pred['Sentence']

# %%
X_train_neural_network, X_test_neural_network, y_train_neural_network, y_test_neural_network = train_test_split(data, y_neural_network, test_size=0.30, random_state=42)

# %% [markdown]
# Save the index to join with facets.

# %%
index_export = X_pred.index

# %%
X_train_neural_network, X_test_neural_network, X_pred_neural_network = preprocessing_neural_network(
    X_train, X_test, X_pred, max_features=10000, max_words=120, num_classes=3)

# %%
data.shape
# Out:
# (5658,)

# %%
X_test_neural_network.shape
# Out:
# (1698, 120)

# %% [markdown]
# Export data.

# %%
export(data,"data_clean_all_data_annotate")
export(label,"label_clean_all_data_annotate")
export(tf_idf_train,"tf_idf_train_all_data_annotate")
export(tf_idf_test,"tf_idf_test_all_data_annotate")
export(y_test,"y_test_all_data_annotate")
export(y_train,"y_train_all_data_annotate")
export(X_train_neural_network,"X_train_neural_network")
export(X_test_neural_network,"X_test_neural_network")
export(y_train_neural_network,"y_train_neural_network")
export(y_test_neural_network,"y_test_neural_network")
export(index_export, "index_X_pred_neural_network")
export(X_pred_neural_network, "X_pred_neural_network")
# Out:
# Matrice de data_clean_all_data_annotate enregistrée
# Matrice de label_clean_all_data_annotate enregistrée
# Matrice de tf_idf_train_all_data_annotate enregistrée
# Matrice de tf_idf_test_all_data_annotate enregistrée
# Matrice de y_test_all_data_annotate enregistrée
# Matrice de y_train_all_data_annotate enregistrée
# Matrice de X_train_neural_network enregistrée
# Matrice de X_test_neural_network enregistrée
# Matrice de y_train_neural_network enregistrée
# Matrice de y_test_neural_network enregistrée
# Matrice de index_X_pred_neural_network enregistrée
# Matrice de X_pred_neural_network enregistrée

# %% [markdown]
# # <center> END
